# %%
import pandas as pd
import geohash2
import requests

# %%
from tqdm import tqdm

# %%
level2 = ['y','v']
level34 = ['b','c','f','g','u','v','y','z','8','9','d','e','s','t','w','x','2','3','6','7','k','m','q','r','0','1','4','5','h','j','n','p']

geohash_list = []
for i in level2:
    for j in level34:
        for k in level34:
            geohash_johap = 'w' + i + j + k
            geohash_list.append(geohash_johap)

print(len(geohash_list))
# Out:
# 2048

# %%
import requests
import json
from pprint import pprint

# 매물 목록 수집
def getRoomList( geohash_id ):
    REQUEST_URL = ROOM_LIST_URL.format( geohash_id=geohash_id )
 
    req = requests.get( REQUEST_URL )
    if req.status_code == 200:
        data = json.loads( req.text )
        for i in data['items']:
            item_ids.append(i['item_id'])
            item_lats.append(i['lat'])
            item_lngs.append(i['lng'])
 
        return [ item["item_id"] for item in data["items"] if 'ad_agent' not in item ]
 
    return list()
 
# 매물 상세정보 수집
def getRoomInfo( room_id ):
    REQUEST_URL = ROOM_INFO_URL.format( room_id=room_id )
 
    req = requests.get( REQUEST_URL )
    if req.status_code == 200:
        data = json.loads( req.text )
        return data
    
    return None
 
# 매물 상세정보를 입맞대로 파싱
def parseRoomInfo( room_info, find_text=None ):
    parsed_data = {
        "url": 'https://www.zigbang.com/home/oneroom/items/{}'.format( room_info["item"].get("item_id") )
        , "item_id": room_info["item"].get("item_id")
        , "제목": room_info["item"].get("title")
        , "주소": ( room_info["item"].get("local1"), room_info["item"].get("local2"), room_info["item"].get("local3"), room_info["item"].get("local4") )
        , "설명": {
            "요약": room_info["item"].get("agent_comment")
            , "상세내용": room_info["item"].get("description")
        }
        , "정보": {
            "사진": room_info["item"].get("images")
            , "전세/월세": room_info["item"].get("sales_type")
            , "방": room_info["item"].get("service_type")
            , "층수": "{}/{}".format( room_info["item"].get("floor"),  room_info["item"].get("floor_all") )
        }
        , "비용": {
            "관리비": room_info["item"].get("manage_cost")
            , "보증금액": room_info["item"].get("보증금액")
            , "월세금액": room_info["item"].get("월세금액")
        }
        , "면적": {
            "공급면적_m2": room_info["item"].get("공급면적_m2")
            , "대지권면적_m2": room_info["item"].get("대지권면적_m2")
            , "전용면적_m2": room_info["item"].get("전용면적_m2")
        }
        , "중개사": room_info["agent"].get("owner")
    }
    if find_text is not None:
        if  parsed_data["설명"]["상세내용"].find( find_text ) > 0:
            return parsed_data
        return None
    return parsed_data



SUBWAY_LIST_URL="https://apis.zigbang.com/property/biglab/subway/all?"
ROOM_LIST_URL="https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={geohash_id}&needHasNoFiltered=true&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸"
ROOM_INFO_URL="https://apis.zigbang.com/v2/items/{room_id}"

item_ids = []
item_lats = []
item_lngs = []
item_info = []

for i in geohash_list:
    # 매물 목록 수집 요청
    room_list = getRoomList( i )

    for room_id in tqdm(room_list):
        # 매물 상세 정보 수집 요청
        room_info = getRoomInfo( room_id )
        # 매물 상세정보를 입맞대로 파싱
        item_info.append(parseRoomInfo( room_info))
# Out:
# 0it [00:00, ?it/s]
#   5%|███▉                                                                           | 191/3862 [00:31<10:05,  6.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 78>()
#      80 room_list = getRoomList( i )
#      82 for room_id in tqdm(room_list):
#      83     # 매물 상세 정보 수집 요청
# ---> 84     room_info = getRoomInfo( room_id )
#      85     # 매물 상세정보를 입맞대로 파싱
#      86     item_info.append(parseRoomInfo( room_info))
#
# Input In [4], in getRoomInfo(room_id)
#      22 def getRoomInfo( room_id ):
#      23     REQUEST_URL = ROOM_INFO_URL.format( room_id=room_id )
# ---> 25     req = requests.get( REQUEST_URL )
#      26     if req.status_code == 200:
#      27         data = json.loads( req.text )
#
# File ~\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
# ...

# %%
item_info
# Out:
# [{'url': 'https://www.zigbang.com/home/oneroom/items/34247724',
#   'item_id': 34247724,
#   '제목': '🌞5.5평🌞채광좋은 남향 풀옵션 원룸🏡전세대출가능',
#   '주소': ('서울시', '노원구', '월계동', None),
#   '설명': {'요약': '🚅젊은 대표가 운영하는 신속한 드림부동산은 광운대역 2번 출구 바로 앞에 있습니다\r\n\r\n📺유튜브에  [집스커버리]  채널을 검색하시면 집을 영상으로 자세히 볼 수 있습니다\r\n\r\n📸드림부동산은 고객을 위해 초고화질 디테일한 풀HD 방 사진을 제공합니다\r\n\r\n🚔 1:1 프리미엄 서비스 100% 예약제로 운영되며 차량으로 픽업서비스 제공됩니다\r\n\r\n 👮소중한 여러분을 위한 철저한 권리분석과 꼼꼼한 계약진행을 도와드립니다 \r\n\r\n👌🏻 24시간 전화문의 가능합니다  카카오톡ID : homescovery',
#    '상세내용': '💿주택가에 위치하여 조용하고 아늑합니다\r\n💿주인분께서 관리를 철처하게 하여 불편사항있으면 바로 해결가능합니다\r\n💿분리수거잘되며 CCTV완비되어 있습니다\n 22.11.23에 직방에 등록된 매물입니다.'},
#   '정보': {'사진': ['https://ic.zigbang.com/ic/items/34247724/1.jpg',
#     'https://ic.zigbang.com/ic/items/34247724/2.jpg',
#     'https://ic.zigbang.com/ic/items/34247724/3.jpg',
#     'https://ic.zigbang.com/ic/items/34247724/4.jpg',
#     'https://ic.zigbang.com/ic/items/34247724/5.jpg',
#     'https://ic.zigbang.com/ic/items/34247724/6.jpg',
# ...

# %%
from datetime import datetime
from bs4 import BeautifulSoup
import pandas as pd
import requests
import json
import sys
import re
import os


class crawl_zigbang_info:
    # 수행기능 : 특정 지역 아이템 리스트를 가진 URL 링크를 입력하면 각 방에 대한 정보를 csv 파일 및 jpg 파일로 변환하여 저장
    # url형식 : https://api.zigbang.com/v1/items?detail=true&item_ids=6128393&~~~&~~~&~~~
    def crawl_items(self, zigbang_url):
        response = requests.get(zigbang_url)
        init_data = json.loads(response.text)

        rooms_info = init_data.get('items')
        self.save_info_to_csv(rooms_info)
        
        pattern = r'[0-9]{7}'
        item_ids = re.findall(pattern, zigbang_url)
        self.save_image(item_ids)

    # 수행기능 : 각 매물에 대한 정보를 컬럼별로 나누어 '월.일_순서.csv' 파일로 저장
    # 파라미터 : 리스트 ( 각 매물에 세부 정보 )
    def save_info_to_csv(self, rooms_info):
        df = pd.DataFrame(
            columns=["제목","룸 타입", "보증금/월세", "관리비", "부가옵션", "가까운 역", "건물층수",\
                     "엘리베이터", "집 주소", "입주일", "업자이름", "업자번호", "대표번호", "업자주소",\
                     "오픈상태", "현재상태", "비밀메모", "부가설명"]
            )
        
        for idx, item in enumerate(rooms_info):
            room = item.get('item')
            
            df.loc[idx] = [
                room['title'],    # 제목
                room['building_type'] + ' / ' + room['room_type'],    # 룸타입
                str(room['deposit']) +  ' / ' + str(room['rent']),    # 보증금/월세
                room['manage_cost'],    # 관리비
                room['options'],        # 부가옵션
                room['near_subways'],   # 가까운 역 
                str(room['floor']) + ' / ' + str(room['floor_all']),  # 건물층수
                room['elevator'],       # 엘리베이터
                str(room['address1']) + ' ' + str(room['address2']),  # 집 주소
                room['movein_date'],    # 입주일
                room['user_name'],      # 업자이름
                room['user_mobile'],    # 업자번호
                room['agent_phone'],    # 대표번호
                room['agent_address1'], # 업자주소
                room['is_status_open'], # 오픈상태
                room['status'],         # 현재상태
                room['secret_memo'],    # 비밀메모
                room['description'].replace("\n\n","\n"),  # 부가설명
            ]

        count = 1
        currentTime = datetime.now()
        while True:
            csv_path = os.path.join('/home/giftbott', 'data', 'zigbang')
            file_name = str(currentTime.month) + '.' + str(currentTime.day) + '_'
            file_name = file_name + str(count) + '.csv'
            csv_file = os.path.join(csv_path, file_name)
            
            if os.path.exists(csv_file):
                count += 1
            else:
                break
        
        df.to_csv(csv_file)
    
    # 수행기능 : 방 이미지를 '원하는 경로/방id/번호.jpg' 에 저장
    # 파라미터 : 리스트 ( 직방 각 매물에 대한 ID 리스트 )
    def save_image(self, item_ids):
        for id in item_ids:
            detail_url = 'https://www.zigbang.com/items1/{id}'.format(id = id)
            img_path = os.path.join('/home/giftbott', 'data','zigbang', id)

            # 디렉토리가 있으면 이미 이미지가 저장된 상태이므로 pass
            if not os.path.exists(img_path):
                os.makedirs(img_path)

                detail_response = requests.get(detail_url)
                dom = BeautifulSoup(detail_response.content, 'html.parser')
                img_lists = dom.select('.bxslider img')

                for idx, image in enumerate(img_lists):
                    img_name = os.path.join(img_path, (str)(idx + 1) + '.jpg')

                    with open(img_name, 'wb') as f:
                        f.write(requests.get(image['src']).content)

                        
def crawl(zigbang_url):
    crawl = crawl_zigbang_info()
    crawl.crawl_items(zigbang_url)
